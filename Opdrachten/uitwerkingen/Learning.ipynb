# %% [markdown]
# # Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_train = pd.read_csv('../datasets/iris_training_dataset.csv', index_col=0)
df_test = pd.read_csv('../datasets/iris_test_dataset.csv', index_col=0)

# %%
feature_names = ['sepal_length_scaled', 'sepal_width_scaled', 'petal_length_scaled', 'petal_width_scaled']
target_name = 'species'

df_train_features = df_train[feature_names]
df_train_target = df_train[target_name]
df_test_features = df_test[feature_names]
df_test_target = df_test[target_name]

# %% [markdown]
# ## Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_classifier = KNeighborsClassifier(n_neighbors = 5)

knn_classifier.fit(df_train_features, df_train_target)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Predict

# %%
df_test['5NN_predicted'] = knn_classifier.predict(df_test_features)

# %%
    df_test['5NN_correct'] = df_test['5NN_predicted'] == df_test['species']

# %%
df_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 30            4.8          3.1           1.6          0.2
# 40            5.0          3.5           1.3          0.3
# 71            6.1          2.8           4.0          1.3
# 5             5.4          3.9           1.7          0.4
# 83            6.0          2.7           5.1          1.6
# 18            5.7          3.8           1.7          0.3
# 53            5.5          2.3           4.0          1.3
# 12            4.8          3.0           1.4          0.1
# 103           6.3          2.9           5.6          1.8
# 67            5.8          2.7           4.1          1.0
# 104           6.5          3.0           5.8          2.2
# 59            5.2          2.7           3.9          1.4
# 16            5.4          3.9           1.3          0.4
# 76            6.8          2.8           4.8          1.4
# 0             5.1          3.5           1.4          0.2
# 56            6.3          3.3           4.7          1.6
# 26            5.0          3.4           1.6          0.4
# 117           7.7          3.8           6.7          2.2
# 124           6.7          3.3           5.7          2.1
# 149           5.9          3.0           5.1          1.8
# 123           6.3          2.7           4.9          1.8
# 8             4.4          2.9           1.4          0.2
# 142           5.8          2.7           5.1          1.9
# 75            6.6          3.0           4.4          1.4
# 24            4.8          3.4           1.9          0.2
# 97            6.2          2.9           4.3          1.3
# 120           6.9          3.2           5.7          2.3
# 107           7.3          2.9           6.3          1.8
# 112           6.8          3.0           5.5          2.1
# 129           7.2          3.0           5.8          1.6
# 6             4.6          3.4           1.4          0.3
# 82            5.8          2.7           3.9          1.2
# 131           7.9          3.8           6.4          2.0
# 146           6.3          2.5           5.0          1.9
# 54            6.5          2.8           4.6          1.5
# 79            5.7          2.6           3.5          1.0
# 72            6.3          2.5           4.9          1.5
# 10            5.4          3.7           1.5          0.2
# 28            5.2          3.4           1.4          0.2
# 133           6.3          2.8           5.1          1.5
# 135           7.7          3.0           6.1          2.3
# 60            5.0          2.0           3.5          1.0
# 125           7.2          3.2           6.0          1.8
# 138           6.0          3.0           4.8          1.8
# 57            4.9          2.4           3.3          1.0
#
#      sepal_length_scaled  sepal_width_scaled  petal_length_scaled  \
# 30             -1.240068            0.095289            -1.177015
# 40             -0.988217            1.026015            -1.347401
# 71              0.396966           -0.602756             0.186072
# 5              -0.484514            1.956741            -1.120220
# 83              0.271040           -0.835438             0.810821
# 18             -0.106737            1.724060            -1.120220
# 53             -0.358588           -1.766164             0.186072
# 12             -1.240068           -0.137393            -1.290606
# 103             0.648817           -0.370075             1.094797
# 67              0.019189           -0.835438             0.242868
# 104             0.900669           -0.137393             1.208388
# 59             -0.736366           -0.835438             0.129277
# 16             -0.484514            1.956741            -1.347401
# 76              1.278446           -0.602756             0.640435
# 0              -0.862291            1.026015            -1.290606
# 56              0.648817            0.560652             0.583640
# 26             -0.988217            0.793333            -1.177015
# 117             2.411777            1.724060             1.719546
# 124             1.152520            0.560652             1.151593
# 149             0.145114           -0.137393             0.810821
# 123             0.648817           -0.835438             0.697230
# 8              -1.743771           -0.370075            -1.290606
# 142             0.019189           -0.835438             0.810821
# 75              1.026594           -0.137393             0.413254
# 24             -1.240068            0.793333            -1.006629
# 97              0.522892           -0.370075             0.356458
# 120             1.404372            0.327970             1.151593
# 107             1.908074           -0.370075             1.492365
# 112             1.278446           -0.137393             1.038002
# 129             1.782149           -0.137393             1.208388
# 6              -1.491920            0.793333            -1.290606
# 82              0.019189           -0.835438             0.129277
# 131             2.663629            1.724060             1.549160
# 146             0.648817           -1.300801             0.754025
# 54              0.900669           -0.602756             0.526844
# 79             -0.106737           -1.068119            -0.097904
# 72              0.648817           -1.300801             0.697230
# 10             -0.484514            1.491378            -1.233811
# 28             -0.736366            0.793333            -1.290606
# 133             0.648817           -0.602756             0.810821
# 135             2.411777           -0.137393             1.378774
# 60             -0.988217           -2.464209            -0.097904
# 125             1.782149            0.327970             1.321979
# 138             0.271040           -0.137393             0.640435
# 57             -1.114143           -1.533482            -0.211495
#
#      petal_width_scaled     species 3NN_predicted  3NN_correct 5NN_predicted  \
# 30            -1.253518      setosa        setosa         True        setosa
# 40            -1.125732      setosa        setosa         True        setosa
# 71             0.152126  versicolor    versicolor         True    versicolor
# 5             -0.997947      setosa        setosa         True        setosa
# 83             0.535484  versicolor     virginica        False     virginica
# 18            -1.125732      setosa        setosa         True        setosa
# 53             0.152126  versicolor    versicolor         True    versicolor
# 12            -1.381304      setosa        setosa         True        setosa
# 103            0.791055   virginica     virginica         True     virginica
# 67            -0.231232  versicolor    versicolor         True    versicolor
# 104            1.302199   virginica     virginica         True     virginica
# 59             0.279912  versicolor    versicolor         True    versicolor
# 16            -0.997947      setosa        setosa         True        setosa
# 76             0.279912  versicolor    versicolor         True    versicolor
# 0             -1.253518      setosa        setosa         True        setosa
# 56             0.535484  versicolor    versicolor         True    versicolor
# 26            -0.997947      setosa        setosa         True        setosa
# 117            1.302199   virginica     virginica         True     virginica
# 124            1.174413   virginica     virginica         True     virginica
# 149            0.791055   virginica    versicolor        False    versicolor
# 123            0.791055   virginica     virginica         True     virginica
# 8             -1.253518      setosa        setosa         True        setosa
# 142            0.918841   virginica     virginica         True     virginica
# 75             0.279912  versicolor    versicolor         True    versicolor
# 24            -1.253518      setosa        setosa         True        setosa
# 97             0.152126  versicolor    versicolor         True    versicolor
# 120            1.429984   virginica     virginica         True     virginica
# 107            0.791055   virginica     virginica         True     virginica
# 112            1.174413   virginica     virginica         True     virginica
# 129            0.535484   virginica     virginica         True     virginica
# 6             -1.125732      setosa        setosa         True        setosa
# 82             0.024340  versicolor    versicolor         True    versicolor
# 131            1.046627   virginica     virginica         True     virginica
# 146            0.918841   virginica     virginica         True     virginica
# 54             0.407698  versicolor    versicolor         True    versicolor
# 79            -0.231232  versicolor    versicolor         True    versicolor
# 72             0.407698  versicolor     virginica        False     virginica
# 10            -1.253518      setosa        setosa         True        setosa
# 28            -1.253518      setosa        setosa         True        setosa
# 133            0.407698   virginica    versicolor        False    versicolor
# 135            1.429984   virginica     virginica         True     virginica
# 60            -0.231232  versicolor    versicolor         True    versicolor
# 125            0.791055   virginica     virginica         True     virginica
# 138            0.791055   virginica    versicolor        False    versicolor
# 57            -0.231232  versicolor    versicolor         True    versicolor
#
#      5NN_correct
# 30          True
# 40          True
# 71          True
# 5           True
# 83         False
# 18          True
# 53          True
# 12          True
# 103         True
# 67          True
# 104         True
# 59          True
# 16          True
# 76          True
# 0           True
# 56          True
# 26          True
# 117         True
# 124         True
# 149        False
# 123         True
# 8           True
# 142         True
# 75          True
# 24          True
# 97          True
# 120         True
# 107         True
# 112         True
# 129         True
# 6           True
# 82          True
# 131         True
# 146         True
# 54          True
# 79          True
# 72         False
# 10          True
# 28          True
# 133        False
# 135         True
# 60          True
# 125         True
# 138        False
# 57          True
