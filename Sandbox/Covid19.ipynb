# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'covid19_worldwide.csv'

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      10/06/2020   10      6  2020    542      15             Afghanistan
# 1      09/06/2020    9      6  2020    575      12             Afghanistan
# 2      08/06/2020    8      6  2020    791      30             Afghanistan
# 3      07/06/2020    7      6  2020    582      18             Afghanistan
# 4      06/06/2020    6      6  2020    915       9             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 22587  25/03/2020   25      3  2020      0       0                Zimbabwe
# 22588  24/03/2020   24      3  2020      0       1                Zimbabwe
# 22589  23/03/2020   23      3  2020      0       0                Zimbabwe
# 22590  22/03/2020   22      3  2020      1       0                Zimbabwe
# 22591  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018 continentExp
# ...

# %%
list(df['countriesAndTerritories'].unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua_and_Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba',
#  'Bosnia_and_Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British_Virgin_Islands',
#  'Brunei_Darussalam',
#  'Bulgaria',
#  'Burkina_Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape_Verde',
#  'Cases_on_an_international_conveyance_Japan',
#  'Cayman_Islands',
#  'Central_African_Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa_Rica',
#  'Cote_dIvoire',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  'Democratic_Republic_of_the_Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
# ...

# %%
df[df['countriesAndTerritories']=='Netherlands']
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 14675  10/06/2020   10      6  2020    164      15             Netherlands
# 14676  09/06/2020    9      6  2020    165       3             Netherlands
# 14677  08/06/2020    8      6  2020    239       2             Netherlands
# 14678  07/06/2020    7      6  2020    183       6             Netherlands
# 14679  06/06/2020    6      6  2020    210      15             Netherlands
# ...           ...  ...    ...   ...    ...     ...                     ...
# 14833  04/01/2020    4      1  2020      0       0             Netherlands
# 14834  03/01/2020    3      1  2020      0       0             Netherlands
# 14835  02/01/2020    2      1  2020      0       0             Netherlands
# 14836  01/01/2020    1      1  2020      0       0             Netherlands
# 14837  31/12/2019   31     12  2019      0       0             Netherlands
#
#       geoId countryterritoryCode  popData2018 continentExp
# ...

# %%
df.dtypes
# Out:
# dateRep                     object
# day                          int64
# month                        int64
# year                         int64
# cases                        int64
# deaths                       int64
# countriesAndTerritories     object
# geoId                       object
# countryterritoryCode        object
# popData2018                float64
# continentExp                object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['dateRep'], format='%d/%m/%Y')

# %%
df[['date','cases']].sort_values('date')
# Out:
#             date  cases
# 8027  2019-12-31      0
# 16095 2019-12-31      0
# 4593  2019-12-31     27
# 20119 2019-12-31      0
# 1792  2019-12-31      0
# ...          ...    ...
# 11348 2020-06-10    245
# 5578  2020-06-10    153
# 5415  2020-06-10     54
# 22071 2020-06-10    159
# 0     2020-06-10    542
#
# [22592 rows x 2 columns]

# %%
df.dtypes
# Out:
# dateRep                            object
# day                                 int64
# month                               int64
# year                                int64
# cases                               int64
# deaths                              int64
# countriesAndTerritories            object
# geoId                              object
# countryterritoryCode               object
# popData2018                       float64
# continentExp                       object
# date                       datetime64[ns]
# dtype: object

# %%
df[df['countriesAndTerritories']=='Netherlands'].sort_values(by=['date'])
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 14837  31/12/2019   31     12  2019      0       0             Netherlands
# 14836  01/01/2020    1      1  2020      0       0             Netherlands
# 14835  02/01/2020    2      1  2020      0       0             Netherlands
# 14834  03/01/2020    3      1  2020      0       0             Netherlands
# 14833  04/01/2020    4      1  2020      0       0             Netherlands
# ...           ...  ...    ...   ...    ...     ...                     ...
# 14679  06/06/2020    6      6  2020    210      15             Netherlands
# 14678  07/06/2020    7      6  2020    183       6             Netherlands
# 14677  08/06/2020    8      6  2020    239       2             Netherlands
# 14676  09/06/2020    9      6  2020    165       3             Netherlands
# 14675  10/06/2020   10      6  2020    164      15             Netherlands
#
# ...

# %%
df_nederland = df.loc[df['countriesAndTerritories']=='Netherlands',
                      ['date','cases','deaths']].sort_values(by=['date'])
df_nederland
# Out:
#             date  cases  deaths
# 14837 2019-12-31      0       0
# 14836 2020-01-01      0       0
# 14835 2020-01-02      0       0
# 14834 2020-01-03      0       0
# 14833 2020-01-04      0       0
# ...          ...    ...     ...
# 14679 2020-06-06    210      15
# 14678 2020-06-07    183       6
# 14677 2020-06-08    239       2
# 14676 2020-06-09    165       3
# 14675 2020-06-10    164      15
#
# [163 rows x 3 columns]

# %%
df_nederland.set_index('date', inplace=True)

# %%
df_nederland.tail(30)
# Out:
#             cases  deaths
# date
# 2020-05-12    161      16
# 2020-05-13    196      54
# 2020-05-14    227      52
# 2020-05-15    270      28
# 2020-05-16    200      53
# 2020-05-17    189      27
# 2020-05-18    125      10
# 2020-05-19    146      14
# 2020-05-20    108      21
# 2020-05-21    198      33
# 2020-05-22    253      27
# 2020-05-23    188      13
# 2020-05-24    176      23
# 2020-05-25    172      11
# 2020-05-26    209       8
# 2020-05-27    133      26
# 2020-05-28    190      15
# 2020-05-29    182      32
# 2020-05-30    176      28
# 2020-05-31    131      20
# 2020-06-01    185       5
# 2020-06-02    103       6
# 2020-06-03    102       5
# 2020-06-04     86      10
# 2020-06-05    209      13
# 2020-06-06    210      15
# 2020-06-07    183       6
# 2020-06-08    239       2
# 2020-06-09    165       3
# 2020-06-10    164      15

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_nederland['cases'].plot()
df_nederland['deaths'].plot()
plt.show()

# %%
df_nederland['cases'].cumsum().plot()
df_nederland['deaths'].cumsum().plot()
plt.show()

# %%
plt.subplot(1, 2, 1)
df_nederland['cases'].cumsum().plot()
plt.subplot(1, 2, 2)
df_nederland['deaths'].cumsum().plot()

# %%
df_total = df[['countriesAndTerritories','cases','deaths']].groupby('countriesAndTerritories').sum()
df_total['mortality'] = df_total['deaths'] / df_total['cases'] * 100
df_total
# Out:
#                          cases  deaths  mortality
# countriesAndTerritories
# Afghanistan              21459     384   1.789459
# Albania                   1299      34   2.617398
# Algeria                  10382     724   6.973608
# Andorra                    852      51   5.985915
# Angola                      96       4   4.166667
# ...                        ...     ...        ...
# Vietnam                    332       0   0.000000
# Western_Sahara              23       1   4.347826
# Yemen                      524     127  24.236641
# Zambia                    1200      10   0.833333
# Zimbabwe                   314       4   1.273885
#
# [210 rows x 3 columns]

# %%
df_total.loc[['Netherlands','United_States_of_America']]
# Out:
#                             cases  deaths  mortality
# countriesAndTerritories
# Netherlands                 47903    6031  12.590026
# United_States_of_America  1979850  112006   5.657297

# %%
df2 = df[['countriesAndTerritories','geoId','popData2018','continentExp']].groupby('countriesAndTerritories').first()
df2
# Out:
#                         geoId  popData2018 continentExp
# countriesAndTerritories
# Afghanistan                AF   37172386.0         Asia
# Albania                    AL    2866376.0       Europe
# Algeria                    DZ   42228429.0       Africa
# Andorra                    AD      77006.0       Europe
# Angola                     AO   30809762.0       Africa
# ...                       ...          ...          ...
# Vietnam                    VN   95540395.0         Asia
# Western_Sahara             EH          NaN       Africa
# Yemen                      YE   28498687.0         Asia
# Zambia                     ZM   17351822.0       Africa
# Zimbabwe                   ZW   14439018.0       Africa
#
# [210 rows x 3 columns]

# %%
df_total = df1.join(df2)
df_total
# Out:
#                          cases  deaths geoId  popData2018 continentExp
# countriesAndTerritories
# Afghanistan              21459     384    AF   37172386.0         Asia
# Albania                   1299      34    AL    2866376.0       Europe
# Algeria                  10382     724    DZ   42228429.0       Africa
# Andorra                    852      51    AD      77006.0       Europe
# Angola                      96       4    AO   30809762.0       Africa
# ...                        ...     ...   ...          ...          ...
# Vietnam                    332       0    VN   95540395.0         Asia
# Western_Sahara              23       1    EH          NaN       Africa
# Yemen                      524     127    YE   28498687.0         Asia
# Zambia                    1200      10    ZM   17351822.0       Africa
# Zimbabwe                   314       4    ZW   14439018.0       Africa
#
# [210 rows x 5 columns]

# %%
df_total['contamination'] = df_total['cases'] / df_total['popData2018'] * 100
df_total['death_percentage'] = df_total['deaths'] / df_total['cases'] * 100
df_total
# Out:
#                          cases  deaths geoId  popData2018 continentExp  \
# countriesAndTerritories
# Afghanistan              21459     384    AF   37172386.0         Asia
# Albania                   1299      34    AL    2866376.0       Europe
# Algeria                  10382     724    DZ   42228429.0       Africa
# Andorra                    852      51    AD      77006.0       Europe
# Angola                      96       4    AO   30809762.0       Africa
# ...                        ...     ...   ...          ...          ...
# Vietnam                    332       0    VN   95540395.0         Asia
# Western_Sahara              23       1    EH          NaN       Africa
# Yemen                      524     127    YE   28498687.0         Asia
# Zambia                    1200      10    ZM   17351822.0       Africa
# Zimbabwe                   314       4    ZW   14439018.0       Africa
#
#                          contamination  death_percentage
# countriesAndTerritories
# ...

# %%
df_total[df_total['continentExp']=='Europe' ].sort_values('contamination', ascending=False)
# Out:
#                           cases  deaths geoId  popData2018 continentExp  \
# countriesAndTerritories
# San_Marino                  688      42    SM      33785.0       Europe
# Holy_See                     12       0    VA       1000.0       Europe
# Andorra                     852      51    AD      77006.0       Europe
# Luxembourg                 4046     110    LU     607728.0       Europe
# Belarus                   50265     282    BY    9485386.0       Europe
# Gibraltar                   176       0    GI      33718.0       Europe
# Belgium                   59437    9619    BE   11422068.0       Europe
# Ireland                   25215    1691    IE    4853506.0       Europe
# Spain                    241966   27136    ES   46723749.0       Europe
# Iceland                    1807      10    IS     353574.0       Europe
# Armenia                   13675     217    AM    2951776.0       Europe
# Sweden                    45924    4717    SE   10183175.0       Europe
# ...

# %%
df_total_europe = df_total.loc[df_total['continentExp']=='Europe'].sort_values('contamination')

fig, axs = plt.subplots(1, 2, figsize=(10,20))

df_total_europe.plot(kind='barh', y='contamination', ax=axs[0])

df_total_europe.plot(kind='barh', y='death_percentage', ax=axs[1])

plt.show()

# %%
df_total_world = df_total.sort_values('contamination', ascending=False)
df_total_world.head(30)
# Out:
#                                               cases  deaths     geoId  \
# countriesAndTerritories
# Cases_on_an_international_conveyance_Japan      696       7  JPG11668
# Qatar                                         71879      62        QA
# San_Marino                                      688      42        SM
# Holy_See                                         12       0        VA
# Andorra                                         852      51        AD
# Bahrain                                       16200      29        BH
# Kuwait                                        33140     273        KW
# Chile                                        142759    2283        CL
# Singapore                                     38514      25        SG
# Luxembourg                                     4046     110        LU
# Peru                                         203736    5738        PE
# United_States_of_America                    1979850  112006        US
# ...

# %%
df_total_world = df_total.dropna().sort_values('contamination')
df_total_world.plot(kind='barh', y='contamination', figsize=(6,40))
plt.xlim(0,2)
plt.show()

# %%
df_total
# Out:
#                          cases  deaths geoId  popData2018 continentExp  \
# countriesAndTerritories
# Afghanistan              21459     384    AF   37172386.0         Asia
# Albania                   1299      34    AL    2866376.0       Europe
# Algeria                  10382     724    DZ   42228429.0       Africa
# Andorra                    852      51    AD      77006.0       Europe
# Angola                      96       4    AO   30809762.0       Africa
# ...                        ...     ...   ...          ...          ...
# Vietnam                    332       0    VN   95540395.0         Asia
# Western_Sahara              23       1    EH          NaN       Africa
# Yemen                      524     127    YE   28498687.0         Asia
# Zambia                    1200      10    ZM   17351822.0       Africa
# Zimbabwe                   314       4    ZW   14439018.0       Africa
#
#                          contamination  death_percentage
# countriesAndTerritories
# ...
