# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("dummy_data.csv", sep=';')

# %%
df
# Out:
#     Naam  Prijs  Aantal
# 0  Rijst      1       3
# 1  Boter      4       2
# 2   Kaas      2       1

# %%
df = pd.DataFrame({"naam":["Peter", "Robin", "Wayne", "Patricia"], 
                   "woonplaats":["Lhee", "Utrecht", "Amsterdam", "Hilversum"],
                   "aantal":[3,2,5,4]})

# %%
df
# Out:
#        naam woonplaats  aantal
# 0     Peter       Lhee       3
# 1     Robin    Utrecht       2
# 2     Wayne  Amsterdam       5
# 3  Patricia  Hilversum       4

# %%
names = list(df.columns)
names[2] = 'N'
df.columns = names
df
# Out:
#        naam woonplaats  N
# 0     Peter       Lhee  3
# 1     Robin    Utrecht  2
# 2     Wayne  Amsterdam  5
# 3  Patricia  Hilversum  4

# %% [markdown]
# ## Inspection

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# naam          string
# woonplaats    string
# N              int64
# dtype: object

# %%
df['woonplaats'] = df['woonplaats'].astype('string')

# %%
df.columns
# Out:
# Index(['naam', 'woonplaats', 'N'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['naam', 'woonplaats', 'aantal'], dtype='object')]

# %%
df.describe()
# Out:
#          aantal
# count  4.000000
# mean   3.500000
# std    1.290994
# min    2.000000
# 25%    2.750000
# 50%    3.500000
# 75%    4.250000
# max    5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   naam        4 non-null      object
#  1   woonplaats  4 non-null      object
#  2   aantal      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.count()
# Out:
# naam          4
# woonplaats    4
# aantal        4
# dtype: int64

# %%
df.head(2)
# Out:
#     naam woonplaats  aantal
# 0  Peter       Lhee       3
# 1  Robin    Utrecht       2

# %% [markdown]
# ## Series

# %%
s = pd.Series([7,4,2,3,6,8,3], name='aantal')

# %%
s
# Out:
# 0    7
# 1    4
# 2    2
# 3    3
# 4    6
# 5    8
# 6    3
# Name: aantal, dtype: int64

# %%
s = df['aantal']
s
# Out:
# 0    3
# 1    2
# 2    5
# 3    4
# Name: aantal, dtype: int64

# %%
s.sort_values()
# Out:
# 1    2
# 0    3
# 3    4
# 2    5
# Name: aantal, dtype: int64

# %% [markdown]
# ## Index

# %%
df
# Out:
#        naam woonplaats  aantal
# 0     Peter       Lhee       3
# 1     Robin    Utrecht       2
# 2     Wayne  Amsterdam       5
# 3  Patricia  Hilversum       4

# %%
df2 = df.set_index('naam')
df2
# Out:
#          woonplaats  aantal
# naam
# Peter          Lhee       3
# Robin       Utrecht       2
# Wayne     Amsterdam       5
# Patricia  Hilversum       4

# %%
df2.reset_index()
# Out:
#        naam woonplaats  aantal
# 0     Peter       Lhee       3
# 1     Robin    Utrecht       2
# 2     Wayne  Amsterdam       5
# 3  Patricia  Hilversum       4

# %% [markdown]
# ## Read data

# %%
# !ls
# Out:
# 7052_95_UntypedDataSet_03052020_113458.csv
# CBS Jan-Dirk.ipynb
# CBS.ipynb
# CBS7.py
# CSV importeren.ipynb
# Covid19.ipynb
# Demo Dataframe.ipynb
# Demo Matplotlib.ipynb
# Demo Numpy Array.ipynb
# Demo Numpy.ipynb
# Demo Pandas 1.ipynb
# Demo Pandas.ipynb
# Demo Standard Library.ipynb
# Demo2 Pandas.ipynb
# Eerste demo-Copy1.ipynb
# Eerste demo.ipynb
# Encoding.ipynb
# GeoPandas.ipynb
# IPython.ipynb
# Intro Numpy - Groep 29.ipynb
# Intro Numpy.ipynb
# Jupyter notebooks les 2.zip
# KNMI.ipynb
# Lineaire regressie.ipynb
# Logaritmisch Regressie.ipynb
# Mijn eerste Jupyter Notebook.ipynb
# Multiple Regression.ipynb
# Naamloos.ipynb
# Numpy Random.ipynb
# Numpy.ipynb
# Opdracht 5.1.ipynb
# Overgangen.ipynb
# Pandas DataFrame.ipynb
# Pandas Plot.ipynb
# Python Basic.ipynb
# Python Basic.ipynb.zip
# Python Basics.ipynb
# Random Walk.ipynb
# Read from internet.ipynb
# Reading ca-500.ipynb
# Regressie.ipynb
# Reshaping a dataframe.ipynb
# Seaborn from Python Data Science Handbook.ipynb
# ...

# %%
filename = '/Users/peter/Computrain/Python voor Data Science/Sandbox/ca-500.csv'
pd.read_csv(filename, delimiter=',')
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
url = 'https://nl.wikipedia.org/wiki/Provincies_van_Nederland'

# %%
df = pd.read_html(url, decimal=',', thousands='.')[0]
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte(land+water) in km²  \
# 0    NaN            Groningen        585866                         2959.68
# 1    NaN  Friesland (Fryslân)        649957                         5748.77
# 2    NaN              Drenthe        493682                         2680.39
# 3    NaN           Overijssel       1162406                         3420.74
# 4    NaN            Flevoland        423021                         2412.31
# 5    NaN           Gelderland       2085952                         5136.31
# 6    NaN              Utrecht       1354834                         1560.05
# 7    NaN        Noord-Holland       2879527                         4091.93
# 8    NaN         Zuid-Holland       3708696                         3307.86
# 9    NaN              Zeeland        383488                         2933.44
# 10   NaN        Noord-Brabant       2562955                         5082.06
# ...

# %%
list(df.columns)
# Out:
# ['Vlag',
#  'Provincie',
#  'Bevolking[1]',
#  'Oppervlakte(land+water) in km²',
#  'Oppervlakte(land) in km²',
#  'inw./km²[2]',
#  'Hoofdstad',
#  'Gemeente met demeeste inwoners']

# %%
df.dtypes
# Out:
# Vlag                              float64
# Provincie                          object
# Bevolking[1]                        int64
# Oppervlakte(land+water) in km²    float64
# Oppervlakte(land) in km²          float64
# inw./km²[2]                         int64
# Hoofdstad                          object
# Gemeente met demeeste inwoners     object
# dtype: object

# %%
df[['Provincie','Hoofdstad','Gemeente met demeeste inwoners','Bevolking[1]']]
# Out:
#               Provincie         Hoofdstad Gemeente met demeeste inwoners  \
# 0             Groningen         Groningen                      Groningen
# 1   Friesland (Fryslân)        Leeuwarden                     Leeuwarden
# 2               Drenthe             Assen                          Emmen
# 3            Overijssel            Zwolle                       Enschede
# 4             Flevoland          Lelystad                         Almere
# 5            Gelderland            Arnhem                       Nijmegen
# 6               Utrecht           Utrecht                        Utrecht
# 7         Noord-Holland           Haarlem                      Amsterdam
# 8          Zuid-Holland          Den Haag                      Rotterdam
# 9               Zeeland        Middelburg                      Terneuzen
# 10        Noord-Brabant  's-Hertogenbosch                      Eindhoven
# 11              Limburg        Maastricht                     Maastricht
#
#     Bevolking[1]
# ...

# %%
df[['Provincie','Bevolking[1]','Oppervlakte(land) in km²']]
# Out:
#               Provincie  Bevolking[1]  Oppervlakte(land) in km²
# 0             Groningen        585866                   2323.94
# 1   Friesland (Fryslân)        649957                   3335.62
# 2               Drenthe        493682                   2632.65
# 3            Overijssel       1162406                   3319.00
# 4             Flevoland        423021                   1411.63
# 5            Gelderland       2085952                   4963.71
# 6               Utrecht       1354834                   1485.46
# 7         Noord-Holland       2879527                   2664.82
# 8          Zuid-Holland       3708696                   2700.07
# 9               Zeeland        383488                   1782.12
# 10        Noord-Brabant       2562955                   4905.46
# 11              Limburg       1117201                   2146.61

# %%
df['Aantal hectare'] = df['Oppervlakte(land) in km²'] * 100

# %%
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte(land+water) in km²  \
# 0    NaN            Groningen        585866                         2959.68
# 1    NaN  Friesland (Fryslân)        649957                         5748.77
# 2    NaN              Drenthe        493682                         2680.39
# 3    NaN           Overijssel       1162406                         3420.74
# 4    NaN            Flevoland        423021                         2412.31
# 5    NaN           Gelderland       2085952                         5136.31
# 6    NaN              Utrecht       1354834                         1560.05
# 7    NaN        Noord-Holland       2879527                         4091.93
# 8    NaN         Zuid-Holland       3708696                         3307.86
# 9    NaN              Zeeland        383488                         2933.44
# 10   NaN        Noord-Brabant       2562955                         5082.06
# ...

# %%
(df['Oppervlakte(land) in km²']*1000000)/df['Bevolking[1]']
# Out:
# 0     3966.674973
# 1     5132.062583
# 2     5332.683792
# 3     2855.284642
# 4     3337.021094
# 5     2379.589751
# 6     1096.414764
# 7      925.436712
# 8      728.037564
# 9     4647.133678
# 10    1913.986004
# 11    1921.417901
# dtype: float64

# %%
df['Bevolking[1]']/df['Oppervlakte(land) in km²']
# Out:
# 0      252.100312
# 1      194.853431
# 2      187.522838
# 3      350.227779
# 4      299.668468
# 5      420.240506
# 6      912.063603
# 7     1080.570920
# 8     1373.555500
# 9      215.186407
# 10     522.469860
# 11     520.448987
# dtype: float64

# %%
df[df['Aantal inwoners'] > 2000000]
# Out:
#     Vlag      Provincie Bevolking[1]  Oppervlakte(land+water) in km²  \
# 5    NaN     Gelderland    2.085.952                         5.13631
# 7    NaN  Noord-Holland    2.879.527                         4.09193
# 8    NaN   Zuid-Holland    3.708.696                         3.30786
# 10   NaN  Noord-Brabant    2.562.955                         5.08206
#
#     Oppervlakte(land) in km²  inw./km²[2]         Hoofdstad  \
# 5                    4.96371      420.000            Arnhem
# 7                    2.66482        1.081           Haarlem
# 8                    2.70007        1.374          Den Haag
# 10                   4.90546      522.000  's-Hertogenbosch
#
#    Gemeente met demeeste inwoners  Aantal hectare  Aantal inwoners
# 5                        Nijmegen         4963.71          2085952
# 7                       Amsterdam         2664.82          2879527
# 8                       Rotterdam         2700.07          3708696
# ...

# %%
df.loc[df['Aantal inwoners'] > 2000000, ['Aantal inwoners', 'Provincie']]
# Out:
#     Aantal inwoners      Provincie
# 5           2085952     Gelderland
# 7           2879527  Noord-Holland
# 8           3708696   Zuid-Holland
# 10          2562955  Noord-Brabant

# %% [markdown]
# ## Sorting

# %%
df.sort_values('Aantal inwoners', ascending=False, inplace=True)

# %%
df
# Out:
#     Vlag            Provincie Bevolking[1]  Oppervlakte(land+water) in km²  \
# 8    NaN         Zuid-Holland    3.708.696                         3.30786
# 7    NaN        Noord-Holland    2.879.527                         4.09193
# 10   NaN        Noord-Brabant    2.562.955                         5.08206
# 5    NaN           Gelderland    2.085.952                         5.13631
# 6    NaN              Utrecht    1.354.834                         1.56005
# 3    NaN           Overijssel    1.162.406                         3.42074
# 11   NaN              Limburg    1.117.201                         2.20985
# 1    NaN  Friesland (Fryslân)      649.957                         5.74877
# 0    NaN            Groningen      585.866                         2.95968
# 2    NaN              Drenthe      493.682                         2.68039
# 4    NaN            Flevoland      423.021                         2.41231
# ...
