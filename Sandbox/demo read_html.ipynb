# %%
import pandas as pd

# %%
url = 'https://nl.wikipedia.org/wiki/Provincies_van_Nederland'

df = pd.read_html(url, decimal=',', thousands='.')[0]
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 0    NaN            Groningen        585866                          2959.68
# 1    NaN  Friesland (Fryslân)        649957                          5748.77
# 2    NaN              Drenthe        493682                          2680.39
# 3    NaN           Overijssel       1162406                          3420.74
# 4    NaN            Flevoland        423021                          2412.31
# 5    NaN           Gelderland       2085952                          5136.31
# 6    NaN              Utrecht       1354834                          1560.05
# 7    NaN        Noord-Holland       2879527                          4091.93
# 8    NaN         Zuid-Holland       3708696                          3307.86
# 9    NaN              Zeeland        383488                          2933.44
# 10   NaN        Noord-Brabant       2562955                          5082.06
# ...

# %%
df.to_csv('provincies.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Vlag                             0 non-null      float64
#  1   Provincie                        12 non-null     object
#  2   Bevolking[1]                     12 non-null     int64
#  3   Oppervlakte (land+water) in km²  12 non-null     float64
#  4   Oppervlakte (land) in km²        12 non-null     float64
#  5   inw./km²[2]                      12 non-null     int64
#  6   Hoofdstad                        12 non-null     object
#  7   Gemeente met de meeste inwoners  12 non-null     object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 896.0+ bytes

# %%
df.drop('Vlag', axis=1, inplace=True)

# %%
df
# Out:
#               Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 0             Groningen        585866                          2959.68
# 1   Friesland (Fryslân)        649957                          5748.77
# 2               Drenthe        493682                          2680.39
# 3            Overijssel       1162406                          3420.74
# 4             Flevoland        423021                          2412.31
# 5            Gelderland       2085952                          5136.31
# 6               Utrecht       1354834                          1560.05
# 7         Noord-Holland       2879527                          4091.93
# 8          Zuid-Holland       3708696                          3307.86
# 9               Zeeland        383488                          2933.44
# 10        Noord-Brabant       2562955                          5082.06
# 11              Limburg       1117201                          2209.85
#
# ...

# %%
df.shape
# Out:
# (12, 7)

# %%
df.dtypes
# Out:
# Provincie                           object
# Bevolking[1]                         int64
# Oppervlakte (land+water) in km²    float64
# Oppervlakte (land) in km²          float64
# inw./km²[2]                          int64
# Hoofdstad                           object
# Gemeente met de meeste inwoners     object
# dtype: object

# %%
df[['Provincie','Hoofdstad','Gemeente met de meeste inwoners']] = df[['Provincie','Hoofdstad','Gemeente met de meeste inwoners']].astype('string')

# %%
df.select_dtypes(include=('int', 'float')).describe()
# Out:
#        Bevolking[1]  Oppervlakte (land+water) in km²  \
# count  1.200000e+01                        12.000000
# mean   1.450632e+06                      3461.949167
# std    1.107181e+06                      1297.173728
# min    3.834880e+05                      1560.050000
# 25%    5.628200e+05                      2613.370000
# 50%    1.139804e+06                      3133.770000
# 75%    2.205203e+06                      4339.462500
# max    3.708696e+06                      5748.770000
#
#        Oppervlakte (land) in km²  inw./km²[2]
# count                  12.000000    12.000000
# mean                 2805.924167   527.416667
# std                  1170.544359   389.059813
# min                  1411.630000   188.000000
# 25%                  2055.487500   242.750000
# 50%                  2648.735000   385.000000
# 75%                  3323.155000   619.500000
# max                  4963.710000  1374.000000

# %%
df['Provincie'].value_counts()
# Out:
# Groningen              1
# Friesland (Fryslân)    1
# Drenthe                1
# Overijssel             1
# Flevoland              1
# Gelderland             1
# Utrecht                1
# Noord-Holland          1
# Zuid-Holland           1
# Zeeland                1
# Noord-Brabant          1
# Limburg                1
# Name: Provincie, dtype: Int64

# %%
df.sort_values('inw./km²[2]')
# Out:
#               Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 2               Drenthe        493682                          2680.39
# 1   Friesland (Fryslân)        649957                          5748.77
# 9               Zeeland        383488                          2933.44
# 0             Groningen        585866                          2959.68
# 4             Flevoland        423021                          2412.31
# 3            Overijssel       1162406                          3420.74
# 5            Gelderland       2085952                          5136.31
# 11              Limburg       1117201                          2209.85
# 10        Noord-Brabant       2562955                          5082.06
# 6               Utrecht       1354834                          1560.05
# 7         Noord-Holland       2879527                          4091.93
# 8          Zuid-Holland       3708696                          3307.86
#
# ...

# %%
df.set_index('Provincie', inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['Provincie','Hoofdstad'], inplace=True)

# %%
df.loc[('Groningen','Groningen')]
# Out:
# Bevolking[1]                          585866
# Oppervlakte (land+water) in km²      2959.68
# Oppervlakte (land) in km²            2323.94
# inw./km²[2]                              252
# Gemeente met de meeste inwoners    Groningen
# Name: (Groningen, Groningen), dtype: object

# %%
df.loc[('Groningen','Groningen')]
# Out:
# Bevolking[1]                          585866
# Oppervlakte (land+water) in km²      2959.68
# Oppervlakte (land) in km²            2323.94
# inw./km²[2]                              252
# Gemeente met de meeste inwoners    Groningen
# Name: (Groningen, Groningen), dtype: object

# %%
df.reset_index(inplace=True)

# %%
df[['Provincie','Hoofdstad']]
# Out:
#               Provincie         Hoofdstad
# 0             Groningen         Groningen
# 1   Friesland (Fryslân)        Leeuwarden
# 2               Drenthe             Assen
# 3            Overijssel            Zwolle
# 4             Flevoland          Lelystad
# 5            Gelderland            Arnhem
# 6               Utrecht           Utrecht
# 7         Noord-Holland           Haarlem
# 8          Zuid-Holland          Den Haag
# 9               Zeeland        Middelburg
# 10        Noord-Brabant  's-Hertogenbosch
# 11              Limburg        Maastricht

# %%
df[df['Provincie'].str.contains('Holland')]
# Out:
#        Provincie Hoofdstad  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 7  Noord-Holland   Haarlem       2879527                          4091.93
# 8   Zuid-Holland  Den Haag       3708696                          3307.86
#
#    Oppervlakte (land) in km²  inw./km²[2] Gemeente met de meeste inwoners
# 7                    2664.82         1081                       Amsterdam
# 8                    2700.07         1374                       Rotterdam

# %%
df.loc[df['Provincie'].str.contains('Holland'), 'Provincie':'Bevolking[1]']
# Out:
#        Provincie Hoofdstad  Bevolking[1]
# 7  Noord-Holland   Haarlem       2879527
# 8   Zuid-Holland  Den Haag       3708696
