# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', sep = ';')
df
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
x = df['Father'].values
y = df['Son'].values

# %%
plt.scatter(x, y)
plt.xlabel('Fathers')
plt.ylabel('Sons')
plt.show()

# %%
m = np.corrcoef(x, y)
pearson = m[0, 1]

# %%
print(f'Pearson correlatie coefficient: {pearson:.3f}')
# Out:
# Pearson correlatie coefficient: 0.501

# %%
coefs = np.polyfit(x, y, 1)
coefs
# Out:
# array([ 0.51400591, 33.89280054])

# %%
model = np.poly1d(coefs)

# %%
y_predicted = model(x)

# %%
plt.scatter(x, y, marker='.', color='green', alpha=0.5)
plt.plot(x, y_predicted, color = 'red')

plt.show()

# %%
import seaborn as sns

sns.lmplot(df, x='Father', y='Son', markers='.')
