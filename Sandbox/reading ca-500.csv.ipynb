# %%
import pandas as pd

# %%
filename = '../opdrachten/datasets/ca-500.csv'

# %%
df = pd.read_csv(filename, sep=';')

# %%
df
# Out:
#     first_name   last_name                    company_name  \
# 0    Francoise     Kohlman               Riebesell, H F Jr
# 1       Kendra      Yandow               Deloitte & Touche
# 2      Lourdes     Beliles               Oklahoma Neon Inc
# 3       Hannah    Helmcamp              M B A Paint Stores
# 4          Tom       Sport       Sheraton Shreveport Hotel
# ..         ...         ...                             ...
# 495       Erin       Lafoy             Curtiss Wright Corp
# 496  Kassandra     Batdorf        Phelps Tool & Die Co Inc
# 497     Leslee  Bredernitz         Factory Mattress Outlet
# 498     Daniel      Cisney  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio       Fower      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# 1           6 Arch St #9757          Alcida       NB  E8J 2C4  506-363-1526
# ...

# %%
df.describe()
# Out:
#        first_name last_name   company_name        address     city province  \
# count         500       500            500            500      500      500
# unique        477       497            491            500      227       10
# top         Frank    Mckeon  Kinkos Copies  18 Cameron St  Calgary       ON
# freq            3         2              3              1       19      175
#
#          postal        phone1        phone2             email  \
# count       500           500           500               490
# unique      491           500           500               488
# top     G4W 3G6  450-339-6016  905-995-7113  f.neelon@cox.net
# freq          2             1             1                 2
#
#                                 web date_of_birth
# count                           500           500
# unique                          491           495
# top     http://www.kinkoscopies.com    1971-06-21
# freq                              3             2

# %%
df['first_name']
# Out:
# 0      Francoise
# 1         Kendra
# 2        Lourdes
# 3         Hannah
# 4            Tom
#          ...
# 495         Erin
# 496    Kassandra
# 497       Leslee
# 498       Daniel
# 499      Antonio
# Name: first_name, Length: 500, dtype: object

# %%
df[['first_name','last_name']]
# Out:
#     first_name   last_name
# 0    Francoise     Kohlman
# 1       Kendra      Yandow
# 2      Lourdes     Beliles
# 3       Hannah    Helmcamp
# 4          Tom       Sport
# ..         ...         ...
# 495       Erin       Lafoy
# 496  Kassandra     Batdorf
# 497     Leslee  Bredernitz
# 498     Daniel      Cisney
# 499    Antonio       Fower
#
# [500 rows x 2 columns]

# %%
df['name'] = df['first_name'] + ' ' + df['last_name']

# %%
df[['first_name','last_name','name','city']]
# Out:
#     first_name   last_name               name            city
# 0    Francoise     Kohlman  Francoise Kohlman         Windsor
# 1       Kendra      Yandow      Kendra Yandow          Alcida
# 2      Lourdes     Beliles    Lourdes Beliles      Belleville
# 3       Hannah    Helmcamp    Hannah Helmcamp       Vancouver
# 4          Tom       Sport          Tom Sport     LIle-Perrot
# ..         ...         ...                ...             ...
# 495       Erin       Lafoy         Erin Lafoy       Longueuil
# 496  Kassandra     Batdorf  Kassandra Batdorf         Nanaimo
# 497     Leslee  Bredernitz  Leslee Bredernitz          Quebec
# 498     Daniel      Cisney      Daniel Cisney       Beresford
# 499    Antonio       Fower      Antonio Fower  Port Coquitlam
#
# [500 rows x 4 columns]

# %%
df2 = df[df['city'].isin(['Montreal','Vancouver'])]
df2 = df[(df['city']=='Montreal') | (df['city']=='Vancouver')]
df2
# Out:
#     first_name   last_name                   company_name  \
# 3       Hannah    Helmcamp             M B A Paint Stores
# 67      Mammie  Masiejczyk         Arellano, Cecilia S Md
# 69       Janna       Peets          Hastings, Robert R Jr
# 108     Kaycee     Rubarts  A & H Sptc Systems & Matl Inc
# 109      Tesha     Purslow       Butler Tool & Design Inc
# 115      Luisa    Hofbauer        Level Export Sales Corp
# 128      Mindy      Meisel           Gavin, William H Esq
# 140   Jannette      Kylish            Reif, W Michael Esq
# 218    Brandon      Stalma        Royal Title Service Inc
# 225    Bettina     Perkins  Willamette Valley Walnuts Inc
# 233     Harris    Elmquist           New Lans Corporation
# 236     Maddie      Tapian  Sinclair Machine Products Inc
# 239  Steffanie     Palenik          Rosenblum, Donn D Esq
# 315        Val    Tijerina               Mpsi Systems Inc
# 350      Denny     Gilliam         Associated Brokers Inc
# ...

# %%
df2.shape
# Out:
# (12, 13)

# %%
df2 = df.loc[df['city']=='Montreal', ['first_name', 'last_name', 'city', 'email']]
df2
# Out:
#     first_name   last_name      city                      email
# 67      Mammie  Masiejczyk  Montreal  mammie.masiejczyk@cox.net
# 109      Tesha     Purslow  Montreal  tesha.purslow@purslow.com
# 233     Harris    Elmquist  Montreal     helmquist@elmquist.com
# 236     Maddie      Tapian  Montreal      maddie.tapian@aol.com
# 239  Steffanie     Palenik  Montreal      s.palenik@palenik.com
# 315        Val    Tijerina  Montreal       val.tijerina@cox.net
# 350      Denny     Gilliam  Montreal             dennyg@cox.net
# 411      Luann     Tibbles  Montreal      luann_tibbles@cox.net
# 422     Verona     Staiano  Montreal                        NaN
# 424      Rikki       Groom  Montreal          r.groom@groom.org
# 468      Ricki        Wida  Montreal        ricki.wida@wida.com
# 483  Clemencia      Giglio  Montreal   clemencia_giglio@cox.net

# %%
df2.shape
# Out:
# (12, 4)

# %%
df.count()
# Out:
# first_name       500
# last_name        500
# company_name     500
# address          500
# city             500
# province         500
# postal           500
# phone1           500
# phone2           500
# email            490
# web              500
# date_of_birth    500
# name             500
# dtype: int64

# %%
list(df.columns)
# Out:
# ['first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'city',
#  'province',
#  'postal',
#  'phone1',
#  'phone2',
#  'email',
#  'web',
#  'date_of_birth',
#  'name']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df[df['email'].isnull()]
# Out:
#     first_name last_name                   company_name  \
# 207       Long      Lehn              Georgetown Agency
# 209      Lucia    Weekly                       Days Inn
# 215     Nickie   Marrano       Mcinerney Communications
# 258   Bethanie     Pritt         Four Star Label Co Inc
# 281       Sina    Norcia          Misioneros Del Camino
# 319    Shanice    Vosmus      Firm Security Systems Inc
# 323      Essie  Montalgo             Artistic Gifts Inc
# 422     Verona   Staiano               M C Green & Sons
# 425        Nan   Shufelt  Kates Boylston Publicatns Inc
# 487     Annice     Wykle            Hering, Glenn Z Esq
#
#                    address             city province   postal        phone1  \
# 207           8 W 41st Ave       Blainville       QC  J7C 2R9  450-771-5010
# 209          196 Touhy Ave      Scarborough       ON  M1E 3L6  416-870-8070
# 215   7 Saint Nicholas Ave  North Vancouver       BC  V7J 3P8  604-556-1080
# ...

# %%
df.fillna('onbekend', inplace=True)

# %%
df[df['email']=='onbekend']
# Out:
#     first_name last_name                   company_name  \
# 207       Long      Lehn              Georgetown Agency
# 209      Lucia    Weekly                       Days Inn
# 215     Nickie   Marrano       Mcinerney Communications
# 258   Bethanie     Pritt         Four Star Label Co Inc
# 281       Sina    Norcia          Misioneros Del Camino
# 319    Shanice    Vosmus      Firm Security Systems Inc
# 323      Essie  Montalgo             Artistic Gifts Inc
# 422     Verona   Staiano               M C Green & Sons
# 425        Nan   Shufelt  Kates Boylston Publicatns Inc
# 487     Annice     Wykle            Hering, Glenn Z Esq
#
#                    address             city province   postal        phone1  \
# 207           8 W 41st Ave       Blainville       QC  J7C 2R9  450-771-5010
# 209          196 Touhy Ave      Scarborough       ON  M1E 3L6  416-870-8070
# 215   7 Saint Nicholas Ave  North Vancouver       BC  V7J 3P8  604-556-1080
# ...

# %%
df['city'].unique()
# Out:
# array(['Windsor', 'Alcida', 'Belleville', 'Vancouver', 'LIle-Perrot',
#        'Swift Current', 'Baker Brook', 'Delhi', 'Bradford', 'Aurora',
#        'New Waterford', 'North York', 'Red Deer', 'Edmonton',
#        'Fredericton', 'Etobicoke', 'Barrie', 'Calgary', 'Pangman',
#        'Rouyn-Noranda', 'Leduc', 'North Vancouver', 'London', 'Hamilton',
#        'Pierrefonds', 'Laval', 'Yellowhead County', 'Strathroy',
#        'North River', 'Ottawa', 'Becancour', 'Sault Ste. Marie',
#        'Salmon Arm', 'Richmond', 'Vernon', 'Saint-Hyacinthe',
#        'Peterborough', 'Quesnel', 'Regina', 'Matane', 'Abbotsford',
#        'Saint-Damien', 'Miramichi', 'Kitchener', 'Mississauga',
#        'Stoneham-Et-Tewkesbury', 'Nanaimo', 'Saint-Raymond',
#        'St Catharines', 'Quebec', 'Arnprior', 'Lloydminster', 'Cambridge',
#        'Winnipeg', 'St. Johns', 'Montreal', 'Carleton Place', 'Toronto',
#        'Kingston', 'Thorold', 'West Vancouver', 'Lavaltrie', 'Ajax',
# ...

# %%
df['city'].value_counts()
# Out:
# Calgary                     19
# Montreal                    12
# Etobicoke                   11
# Surrey                       9
# North York                   9
#                             ..
# Pickering                    1
# Dauphin                      1
# Saint-Jean-sur-Richelieu     1
# West Vancouver               1
# Dieppe                       1
# Name: city, Length: 227, dtype: int64

# %%
df['first_name'].value_counts()
# Out:
# Frank        3
# Jaime        3
# Hannah       2
# Avery        2
# Denny        2
#             ..
# Carlene      1
# Leoma        1
# Floyd        1
# Georgiana    1
# Sanda        1
# Name: first_name, Length: 477, dtype: int64

# %%
df.sort_values(['city','last_name'])
# Out:
#     first_name  last_name                    company_name  \
# 43      Carole    Crocker             Kolodny, Howard Esq
# 328   Lasandra    Sarchet   Jmr Marketing & Graphics Corp
# 472    Marleen      Waska       Welsch Metal Products Inc
# 402      Janae      Arand           Park Avenue Audio Inc
# 186     Sarina    Emanuel             Burgess Manning Inc
# ..         ...        ...                             ...
# 113     Harley  Cutsforth    Alliance Construction Co Inc
# 280      Paris     Ivaska    Woodstown Natl Bnk & Trst Co
# 27      Hollis  Tesseneer       Feehan Plumbing & Heating
# 305      Zoila   Canonico  Fox Chase Federal Savings Bank
# 191       Dona      Rhule   Birmingham Historical Society
#
#                         address               city province   postal  \
# 43              9 N Central Ave         Abbotsford       BC  V2S 5R3
# 328              1 Highway 71 S         Abbotsford       BC  V2S 2G5
# ...

# %%
df['name'].str.split()
# Out:
# 0      [Francoise, Kohlman]
# 1          [Kendra, Yandow]
# 2        [Lourdes, Beliles]
# 3        [Hannah, Helmcamp]
# 4              [Tom, Sport]
#                ...
# 495           [Erin, Lafoy]
# 496    [Kassandra, Batdorf]
# 497    [Leslee, Bredernitz]
# 498        [Daniel, Cisney]
# 499        [Antonio, Fower]
# Name: name, Length: 500, dtype: object

# %%
df2 = df.set_index(['province','city','last_name']).sort_index()
df2
# Out:
#                                  first_name                  company_name  \
# province city          last_name
# AB       Big Valley    Stakes        Yvette            Stier, Brian E Esq
#          Calgary       Arnoldi         Rene         Cohen, Mortimer S Esq
#                        Bigaud      Marshall        Mpw Communities Of N J
#                        Coughlan     Claudio           Blatt, Harold G Esq
#                        Cupit          Caren  Personal Christianity Chapel
# ...                                     ...                           ...
# SK       Saskatoon     Milionis     Corazon           Ansonia Records Inc
#                        Prinkey         Curt            Bowden, Mona M Esq
#                        Vilven        Darrin                   Metro Press
#          Swift Current Mahlum         Vivan                Record Journal
#                        Torchio      Queenie      Goeman Wood Products Inc
#
# ...

# %%
df3 = df.set_index(['province']).sort_index()
df3.loc['AB']
# Out:
#          first_name    last_name                    company_name  \
# province
# AB         Glendora         Meir        John L Scott Real Estate
# AB            Paola   Westervelt     M K Goulding And Associates
# AB           Kelvin       Skahan    Orourke, Denise Michelle Esq
# AB          Lashaun      Tomasic       Gerald A Coniglio Md/facs
# AB             Noel        Dewer            Market Decisions Inc
# AB           Renato      Geberth                   Super 8 Motel
# AB         Marshall       Bigaud          Mpw Communities Of N J
# AB          William     Pacholec            Boland, William T Jr
# AB            Johna       Pickle                  Park Metal Inc
# AB            Milly         Coin              Schell, Eric F Esq
# AB            Kenia       Lovero       Marc Hotels & Resorts Inc
# AB          Desirae        Demus              L & P Construction
# AB          Claudio     Coughlan             Blatt, Harold G Esq
# ...

# %%
df3.reset_index()
# Out:
#     province first_name   last_name                  company_name  \
# 0         AB   Glendora        Meir      John L Scott Real Estate
# 1         AB      Paola  Westervelt   M K Goulding And Associates
# 2         AB     Kelvin      Skahan  Orourke, Denise Michelle Esq
# 3         AB    Lashaun     Tomasic     Gerald A Coniglio Md/facs
# 4         AB       Noel       Dewer          Market Decisions Inc
# ..       ...        ...         ...                           ...
# 495       SK      Frank      Dudash       Interlink Marketing Inc
# 496       SK   Valentin     Chreene          General Color Co Inc
# 497       SK       Curt     Prinkey            Bowden, Mona M Esq
# 498       SK   Louvenia   Nickelson           L M Mccown & Son Co
# 499       SK  Francesco   Pospishil          Gabriel & Associates
#
#                     address            city   postal        phone1  \
# 0             2 80e E #7867        Edmonton  T5Y 3J7  780-508-2609
# ...

# %%
df['city'].value_counts()
# Out:
# Calgary                     19
# Montreal                    12
# Etobicoke                   11
# Surrey                       9
# North York                   9
#                             ..
# Pickering                    1
# Dauphin                      1
# Saint-Jean-sur-Richelieu     1
# West Vancouver               1
# Dieppe                       1
# Name: city, Length: 227, dtype: int64

# %%
df.groupby('province').count().sort_values('first_name', ascending=False)
# Out:
#           first_name  last_name  company_name  address  city  postal  phone1  \
# province
# ON               175        175           175      175   175     175     175
# QC               116        116           116      116   116     116     116
# BC                72         72            72       72    72      72      72
# AB                42         42            42       42    42      42      42
# NB                30         30            30       30    30      30      30
# NS                23         23            23       23    23      23      23
# SK                21         21            21       21    21      21      21
# MB                12         12            12       12    12      12      12
# NL                 8          8             8        8     8       8       8
# PE                 1          1             1        1     1       1       1
#
#           phone2  email  web  date_of_birth  name
# province
# ON           175    175  175            175   175
# ...

# %%
df['province'].value_counts()
# Out:
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: province, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['province'].value_counts(ascending=True).plot(kind='barh', color='green')
plt.show()

# %%
df['province'].value_counts().plot(kind='bar')
plt.show()

# %%
df['province'].value_counts().plot(kind='pie')
plt.show()
