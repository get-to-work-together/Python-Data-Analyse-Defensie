# %% [markdown]
# # Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
filename = '../Opdrachten/datasets/ca-500.csv'

# %%
df = pd.read_csv(filename)
df.head(10)
# Out:
#   first_name   last_name                 company_name                 address  \
# 0  Francoise     Kohlman            Riebesell, H F Jr      2335 Canton Hwy #6
# 1     Kendra      Yandow            Deloitte & Touche         6 Arch St #9757
# 2    Lourdes     Beliles            Oklahoma Neon Inc     9547 Belmont Rd #21
# 3     Hannah    Helmcamp           M B A Paint Stores  73 Pittsford Victor Rd
# 4        Tom       Sport    Sheraton Shreveport Hotel    447 Commercial St Se
# 5    Queenie     Torchio     Goeman Wood Products Inc         47 Garfield Ave
# 6        Hui       Moltz  A Storage Inn Of Gloucester               3 Mill Rd
# 7     Josefa     Despain            Norman Gale Isuzu      136 W Grand Ave #3
# 8        Lea  Brzozowski       James, Christopher Esq     80 Maplewood Dr #34
# 9      Paola     Kardell               Congress Title           58 Hancock St
#
#             city province   postal        phone1        phone2  \
# ...

# %%
provinces = {
    'ON': 'Ontario',
    'QC': 'Quebec',
}

df['province'].replace(provinces)
# Out:
# 0      Ontario
# 1           NB
# 2      Ontario
# 3           BC
# 4       Quebec
# 5           SK
# 6           NB
# 7      Ontario
# 8      Ontario
# 9      Ontario
# 10          NS
# 11     Ontario
# 12          AB
# 13          AB
# 14          NB
# 15     Ontario
# 16     Ontario
# 17          AB
# 18          SK
# 19      Quebec
# 20          AB
# 21          BC
# 22     Ontario
# 23     Ontario
# 24      Quebec
# 25     Ontario
# 26      Quebec
# 27          AB
# 28     Ontario
# 29          NS
# 30     Ontario
# 31      Quebec
# 32     Ontario
# 33          BC
# 34          BC
# 35          AB
# 36          BC
# 37      Quebec
# 38     Ontario
# 39          BC
# 40     Ontario
# 41          SK
# 42      Quebec
# 43          BC
# 44          SK
# 45          BC
# 46          SK
# 47      Quebec
# 48          NB
# 49     Ontario
# 50     Ontario
# 51      Quebec
# 52     Ontario
# 53          BC
# 54      Quebec
# 55     Ontario
# 56      Quebec
# 57     Ontario
# ...

# %%
df.dtypes
# Out:
# first_name       object
# last_name        object
# company_name     object
# address          object
# city             object
# province         object
# postal           object
# phone1           object
# phone2           object
# email            object
# web              object
# date_of_birth    object
# dtype: object

# %%
df = df.astype('string')

# %%
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    string
#  1   last_name      500 non-null    string
#  2   company_name   500 non-null    string
#  3   address        500 non-null    string
#  4   city           500 non-null    string
#  5   province       500 non-null    string
#  6   postal         500 non-null    string
#  7   phone1         500 non-null    string
#  8   phone2         500 non-null    string
#  9   email          490 non-null    string
#  10  web            500 non-null    string
#  11  date_of_birth  500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), string(11)
# memory usage: 47.0 KB

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city',
#        'province', 'postal', 'phone1', 'phone2', 'email', 'web',
#        'date_of_birth'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df2 = df[['first_name', 'last_name', 'city']]

# %%
df[df['city']=='Montreal']
# Out:
#     first_name   last_name                   company_name  \
# 67      Mammie  Masiejczyk         Arellano, Cecilia S Md
# 109      Tesha     Purslow       Butler Tool & Design Inc
# 233     Harris    Elmquist           New Lans Corporation
# 236     Maddie      Tapian  Sinclair Machine Products Inc
# 239  Steffanie     Palenik          Rosenblum, Donn D Esq
# 315        Val    Tijerina               Mpsi Systems Inc
# 350      Denny     Gilliam         Associated Brokers Inc
# 411      Luann     Tibbles    Macnaughton Einson Graphics
# 422     Verona     Staiano               M C Green & Sons
# 424      Rikki       Groom           Emergency Management
# 468      Ricki        Wida       Collins, Frederick H Esq
# 483  Clemencia      Giglio       Computer System Dynamics
#
#                    address      city province   postal        phone1  \
# 67            14 E 30th St  Montreal       QC  H1E 1R4  514-205-4258
# ...

# %%
df.loc[df['city']=='Montreal', ['first_name', 'last_name', 'city']]
# Out:
#     first_name   last_name      city
# 67      Mammie  Masiejczyk  Montreal
# 109      Tesha     Purslow  Montreal
# 233     Harris    Elmquist  Montreal
# 236     Maddie      Tapian  Montreal
# 239  Steffanie     Palenik  Montreal
# 315        Val    Tijerina  Montreal
# 350      Denny     Gilliam  Montreal
# 411      Luann     Tibbles  Montreal
# 422     Verona     Staiano  Montreal
# 424      Rikki       Groom  Montreal
# 468      Ricki        Wida  Montreal
# 483  Clemencia      Giglio  Montreal

# %%
df.loc[0, 'city'] = 'XXXXXXXX'

# %%
df.iloc[0:10, [0, 1, 4, -1]]
# Out:
#   first_name   last_name           city date_of_birth
# 0  Francoise     Kohlman       XXXXXXXX    1970-11-05
# 1     Kendra      Yandow         Alcida    1960-02-17
# 2    Lourdes     Beliles     Belleville    2001-12-18
# 3     Hannah    Helmcamp      Vancouver    1955-09-20
# 4        Tom       Sport    LIle-Perrot    1952-08-20
# 5    Queenie     Torchio  Swift Current    1962-11-24
# 6        Hui       Moltz    Baker Brook    1952-02-08
# 7     Josefa     Despain          Delhi    1964-04-28
# 8        Lea  Brzozowski       Bradford    1981-05-27
# 9      Paola     Kardell         Aurora    1969-05-20

# %%
df2.head()
# Out:
#   first_name last_name         city
# 0  Francoise   Kohlman      Windsor
# 1     Kendra    Yandow       Alcida
# 2    Lourdes   Beliles   Belleville
# 3     Hannah  Helmcamp    Vancouver
# 4        Tom     Sport  LIle-Perrot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   first_name     500 non-null    string
#  1   last_name      500 non-null    string
#  2   company_name   500 non-null    string
#  3   address        500 non-null    string
#  4   city           500 non-null    string
#  5   province       500 non-null    string
#  6   postal         500 non-null    string
#  7   phone1         500 non-null    string
#  8   phone2         500 non-null    string
#  9   email          490 non-null    string
#  10  web            500 non-null    string
#  11  date_of_birth  500 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), string(11)
# memory usage: 47.0 KB

# %%
df[df['email'].isna()]
# Out:
#     first_name last_name                   company_name  \
# 207       Long      Lehn              Georgetown Agency
# 209      Lucia    Weekly                       Days Inn
# 215     Nickie   Marrano       Mcinerney Communications
# 258   Bethanie     Pritt         Four Star Label Co Inc
# 281       Sina    Norcia          Misioneros Del Camino
# 319    Shanice    Vosmus      Firm Security Systems Inc
# 323      Essie  Montalgo             Artistic Gifts Inc
# 422     Verona   Staiano               M C Green & Sons
# 425        Nan   Shufelt  Kates Boylston Publicatns Inc
# 487     Annice     Wykle            Hering, Glenn Z Esq
#
#                    address             city province   postal        phone1  \
# 207           8 W 41st Ave       Blainville       QC  J7C 2R9  450-771-5010
# 209          196 Touhy Ave      Scarborough       ON  M1E 3L6  416-870-8070
# 215   7 Saint Nicholas Ave  North Vancouver       BC  V7J 3P8  604-556-1080
# ...

# %%
df[df['email'].duplicated(keep=False)]
# Out:
#     first_name   last_name                    company_name  \
# 13        Huey  Swartzbeck  Southern Idaho Pipe & Stl Corp
# 62       Frank      Neelon     Preferred Service Group Inc
# 207       Long        Lehn               Georgetown Agency
# 209      Lucia      Weekly                        Days Inn
# 215     Nickie     Marrano        Mcinerney Communications
# 258   Bethanie       Pritt          Four Star Label Co Inc
# 281       Sina      Norcia           Misioneros Del Camino
# 319    Shanice      Vosmus       Firm Security Systems Inc
# 321       Huey  Swartzbeck  Southern Idaho Pipe & Stl Corp
# 323      Essie    Montalgo              Artistic Gifts Inc
# 327      Frank      Neelon     Preferred Service Group Inc
# 422     Verona     Staiano                M C Green & Sons
# 425        Nan     Shufelt   Kates Boylston Publicatns Inc
# 487     Annice       Wykle             Hering, Glenn Z Esq
#
# ...
