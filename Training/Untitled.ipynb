# %%
import pandas as pd

# %%
filename = 'data.csv'

df = pd.read_csv(filename, sep = ';', parse_dates=True, dayfirst=True)
df
# Out:
#    Col A    Col B       Col C
# 0     53  aaqaqaa  18-09-2023
# 1   5464     bbbb  19-09-2023
# 2    456     fggf  20-09-2023
# 3    345      ddd  21-09-2023
# 4    453       fv  22-09-2023
# 5    354     fggf  23-09-2023

# %%
pd.to_datetime(df['Col C'], dayfirst=True)
# Out:
# 0   2023-09-18
# 1   2023-09-19
# 2   2023-09-20
# 3   2023-09-21
# 4   2023-09-22
# 5   2023-09-23
# Name: Col C, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col A   6 non-null      int64
#  1   Col B   6 non-null      object
#  2   Col C   6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
import random
numbers = [random.randint(1, 10000) for _ in range(1000)]
numbers
# Out:
# [1656,
#  105,
#  1848,
#  6139,
#  436,
#  871,
#  1059,
#  1199,
#  8495,
#  3483,
#  3459,
#  3351,
#  8777,
#  7618,
#  5436,
#  9151,
#  318,
#  364,
#  8542,
#  8586,
#  2994,
#  3929,
#  8584,
#  5139,
#  5469,
#  3761,
#  2864,
#  752,
#  7980,
#  7134,
#  132,
#  1081,
#  926,
#  7695,
#  9151,
#  1229,
#  3661,
#  4409,
#  7419,
#  7402,
#  7734,
#  8539,
#  1554,
#  3135,
#  6895,
#  4611,
#  1627,
#  6727,
#  4676,
#  910,
#  3728,
#  1177,
#  1732,
#  2036,
#  1466,
#  6102,
#  7525,
#  9990,
#  9037,
#  8744,
#  9730,
#  2145,
#  7278,
#  5775,
#  9486,
#  4536,
#  4442,
#  7219,
#  7275,
#  4380,
#  2587,
#  2581,
#  4012,
#  43,
#  5974,
#  316,
#  4886,
#  850,
#  1986,
#  8344,
#  3045,
#  8145,
#  4459,
#  8317,
#  7714,
#  6069,
#  3368,
#  8479,
#  6360,
#  347,
#  2295,
#  4776,
#  3453,
#  5146,
#  257,
#  4158,
#  6172,
#  6498,
#  83,
#  9194,
#  4040,
#  2147,
#  4540,
#  6661,
#  8505,
#  5358,
#  1486,
#  3698,
#  9172,
#  9191,
#  3193,
#  9167,
#  2298,
# ...

# %%
# %timeit 6573 in numbers
# Out:
# 5.77 µs ± 34.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
s = set(numbers)

# %%
6573 in s
# Out:
# False

# %%
# %timeit 6573 in s
# Out:
# 14.1 ns ± 0.0384 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
